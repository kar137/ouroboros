# %% [markdown]
# # CNN Architecture
#
# The canonical implementation is in `src/models.py`. This notebook provides a lightweight visual reference (sketch) of the 3-layer CNN used in the project.
#
# - Implementation: `src/models.py`
# - Purpose: Quick visual reference for the model architecture

# %% [markdown]
# <img src="../assets/cnn_architecture.png" width="400" height="1800">

# %% [markdown]
# Notes:
#
# - Use `src/models.py` for the canonical implementation and experiments.
